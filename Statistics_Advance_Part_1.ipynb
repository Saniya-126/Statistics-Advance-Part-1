# %% [markdown]
# 1. What is a random variable in probability theory?
# * A random variable is a numerical outcome of a random phenomenon, mapping events from a probability space to real numbers.
#
# 2. What are the types of random variables?
# *  The two main types of random variables are discrete random variables, which take on a countable number of values, and continuous random variables, which can take on any value within a given range.
#
# 3. What is the difference between discrete and continuous distributions?
# * Discrete distributions describe random variables that can take on a finite or countably infinite set of distinct values, such as the number of heads in a series of coin flips. In contrast, continuous distributions represent random variables that can take on any value within a continuous range, such as the height of individuals, and are characterized by probability density functions rather than probability mass functions.
#
# 4. What are probability distribution functions (PDF)?
# * A probability distribution function (PDF) describes the likelihood of a random variable taking on specific values, with discrete random variables using probability mass functions (PMFs) and continuous random variables using probability density functions.
#
# 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
# * Cumulative distribution functions (CDF) represent the probability that a random variable takes on a value less than or equal to a specific point, while probability distribution functions (PDF) describe the likelihood of the random variable taking on exact values.
#
# 6. What is a discrete uniform distribution?
# * A discrete uniform distribution is a probability distribution where a finite number of outcomes are equally likely, meaning each outcome has the same probability of occurring.
#
# 7. What are the key properties of a Bernoulli distribution?
# * The key properties of a Bernoulli distribution include having two possible outcomes (success and failure), a single trial, and a probability (p) of success, with the mean equal to (p) and the variance equal to (p(1-p)).
#
# 8. What is the binomial distribution, and how is it used in probability?
# * The binomial distribution models the number of successes in a fixed number of independent Bernoulli trials, each with the same probability of success, and is used to calculate the likelihood of obtaining a specific number of successes in those trials.
#
# 9. What is the Poisson distribution and where is it applied?
# * The Poisson distribution models the number of events occurring in a fixed interval of time or space, given that these events happen with a known constant mean rate and independently of the time since the last event, and is commonly applied in fields such as telecommunications, traffic flow, and queuing theory.
#
# 10. What is a continuous uniform distribution?
# *  A continuous uniform distribution is a probability distribution where all outcomes within a specified interval are equally likely, characterized by a constant probability density function over that interval.
#
# 11. What are the characteristics of a normal distribution?
# * The characteristics of a normal distribution include a symmetric bell-shaped curve, defined by its mean (which determines the center) and standard deviation (which determines the spread), with approximately 68% of the data falling within one standard deviation of the mean.
#
# 12. What is the standard normal distribution, and why is it important?
# * The standard normal distribution is a special case of the normal distribution with a mean of 0 and a standard deviation of 1, and it is important because it allows for the standardization of scores, enabling comparisons across different normal distributions using z-scores.
#
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# * The Central Limit Theorem (CLT) states that the sampling distribution of the sample mean approaches a normal distribution as the sample size increases, regardless of the original population's distribution, making it critical for inferential statistics and hypothesis testing.
#
# 14. How does the Central Limit Theorem relate to the normal distribution?
# *  The Central Limit Theorem relates to the normal distribution by stating that as the sample size increases, the distribution of the sample means will approximate a normal distribution, even if the original population distribution is not normal.
#
# 15. What is the application of Z statistics in hypothesis testing?
# *  Z statistics are used in hypothesis testing to determine how many standard deviations a sample mean is from the population mean, allowing researchers to assess the significance of their results against a standard normal distribution.
#
# 16. How do you calculate a Z-score, and what does it represent?
# * A Z-score is calculated by subtracting the population mean from the individual data point and then dividing by the population standard deviation, representing the number of standard deviations a data point is from the mean.
#
# 17. What are point estimates and interval estimates in statistics?
# * Point estimates provide a single value estimate of a population parameter, while interval estimates offer a range of values within which the parameter is expected to lie, typically accompanied by a confidence level.
#
# 18. What is the significance of confidence intervals in statistical analysis?
# * Confidence intervals are significant in statistical analysis as they provide a range of values that likely contain the true population parameter, allowing researchers to quantify the uncertainty and reliability of their estimates.
#
# 19. What is the relationship between a Z-score and a confidence interval?
# * The Z-score is used to determine the critical values that define the boundaries of a confidence interval, indicating how many standard deviations away from the mean the interval extends for a specified confidence level.
#
# 20. How are Z-scores used to compare different distributions?
# * Z-scores are used to compare different distributions by standardizing values from different datasets to a common scale, allowing for the assessment of relative positions and probabilities regardless of the original distribution's mean and standard deviation.
#
# 21. What are the assumptions for applying the Central Limit Theorem?
# * The assumptions for applying the Central Limit Theorem include that the samples are independent, the sample size is sufficiently large (typically n ≥ 30), and the population from which the samples are drawn has a finite mean and variance.
#
# 22. What is the concept of expected value in a probability distribution?
# * The expected value in a probability distribution is the long-term average or mean of all possible outcomes, weighted by their probabilities, representing the central tendency of the distribution.
#
# 23. How does a probability distribution relate to the expected outcome of a random variable?
# * A probability distribution describes the likelihood of all possible outcomes of a random variable, and the expected outcome, or expected value, is calculated as the weighted average of these outcomes, reflecting the average result one would anticipate over many trials.

# %%
# Question 1

import numpy as np

def generate_random_variable(low, high):
    """Generate a random variable from a uniform distribution."""
    random_variable = np.random.uniform(low, high)
    return random_variable

low = 1
high = 10

random_value = generate_random_variable(low, high)

print(f"Generated Random Variable: {random_value:.2f}")
# Out:
# Generated Random Variable: 1.72

# %%
# Question 2

import numpy as np
import matplotlib.pyplot as plt

low = 1
high = 10

x = np.arange(low, high + 1)
probabilities = np.ones_like(x) / (high - low + 1)

plt.figure(figsize=(10, 6))
plt.bar(x, probabilities, color='blue', alpha=0.7, edgecolor='black')
plt.title('Probability Mass Function (PMF) of Discrete Uniform Distribution')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.xticks(x)
plt.ylim(0, 0.2)
plt.grid(axis='y', alpha=0.75)

plt.show()

# %%
# Question 3

import numpy as np

def bernoulli_pdf(p):
    """Calculate the PDF of a Bernoulli distribution.

    Args:
        p (float): Probability of success (0 <= p <= 1).

    Returns:
        dict: A dictionary with the probabilities for outcomes 0 and 1.
    """
    if p < 0 or p > 1:
        raise ValueError("Probability p must be between 0 and 1.")

    pdf = {
        0: 1 - p,
        1: p
    }

    return pdf

p = 0.7
pdf = bernoulli_pdf(p)
print(f"PDF of Bernoulli Distribution (p={p}): {pdf}")
# Out:
# PDF of Bernoulli Distribution (p=0.7): {0: 0.30000000000000004, 1: 0.7}

# %%
# Question 4

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

n = 10
p = 0.5
sample_size = 1000

data = np.random.binomial(n, p, size=sample_size)

plt.figure(figsize=(10, 6))
plt.hist(data, bins=np.arange(-0.5, n + 1.5, 1), color='blue', alpha=0.7, edgecolor='black', density=True)
plt.title('Histogram of Simulated Binomial Distribution (n=10, p=0.5)')
plt.xlabel('Number of Successes')
plt.ylabel('Probability Density')
plt.xticks(np.arange(0, n + 1, 1))
plt.grid(axis='y', alpha=0.75)

x = np.arange(0, n + 1)
pmf = binom.pmf(x, n, p)
plt.plot(x, pmf, 'ro-', label='Theoretical PMF', markersize=8)
plt.legend()

plt.show()

# %%
# Question 5

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

lambda_value = 5

x = np.arange(0, 15)

pmf = poisson.pmf(x, lambda_value)

plt.figure(figsize=(10, 6))
plt.bar(x, pmf, color='blue', alpha=0.7, label='Poisson PMF', width=0.5)
plt.title('Poisson Distribution (λ = 5)')
plt.xlabel('Number of Occurrences')
plt.ylabel('Probability')
plt.xticks(x)
plt.grid(axis='y', alpha=0.75)
plt.axhline(0, color='black', linewidth=0.8)
plt.legend()
plt.show()

# %%
# Question 6

import numpy as np
import matplotlib.pyplot as plt

low = 1
high = 10
x = np.arange(low, high + 1)
probabilities = np.ones_like(x) / (high - low + 1)

cdf = np.cumsum(probabilities)

plt.figure(figsize=(10, 6))
plt.step(x, cdf, where='post', color='blue', label='CDF', linewidth=2)
plt.title('Cumulative Distribution Function (CDF) of Discrete Uniform Distribution')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.xticks(x)
plt.grid()
plt.axhline(1, color='red', linestyle='--', label='Cumulative Probability = 1')
plt.legend()
plt.show()

# %%
# Question 7

import numpy as np
import matplotlib.pyplot as plt

low = 0
high = 10
sample_size = 1000

data = np.random.uniform(low, high, size=sample_size)

plt.figure(figsize=(10, 6))
plt.hist(data, bins=30, color='blue', alpha=0.7, edgecolor='black', density=True)
plt.title('Histogram of Continuous Uniform Distribution')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(axis='y', alpha=0.75)

x = np.linspace(low, high, 1000)
pdf = np.ones_like(x) / (high - low)
plt.plot(x, pdf, color='red', linewidth=2, label='Theoretical PDF')
plt.legend()
plt.show()

# %%
# Question 8

import numpy as np
import matplotlib.pyplot as plt

mean = 50
std_dev = 10
sample_size = 1000

data = np.random.normal(loc=mean, scale=std_dev, size=sample_size)

plt.figure(figsize=(10, 6))
plt.hist(data, bins=30, color='blue', alpha=0.7, edgecolor='black')
plt.title('Histogram of Normally Distributed Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.axvline(mean, color='red', linestyle='--', label='Mean')
plt.legend()
plt.show()

# %%
# Question 9

import numpy as np
import matplotlib.pyplot as plt

def calculate_z_scores(data):
    """Calculate Z-scores for a given dataset."""
    mean = np.mean(data)
    std_dev = np.std(data, ddof=0)
    z_scores = (data - mean) / std_dev
    return z_scores

def plot_z_scores(data):
    """Plot the original data and their Z-scores."""
    z_scores = calculate_z_scores(data)

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(data, marker='o', linestyle='-', color='blue')
    plt.title('Original Data')
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.grid()

    plt.subplot(1, 2, 2)
    plt.plot(z_scores, marker='o', linestyle='-', color='orange')
    plt.title('Z-Scores')
    plt.xlabel('Index')
    plt.ylabel('Z-Score')
    plt.axhline(0, color='red', linestyle='--', label='Z=0')
    plt.grid()
    plt.legend()

    plt.tight_layout()
    plt.show()

data = np.random.normal(loc=50, scale=10, size=100)
plot_z_scores(data)

# %%
# Question 10

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


low = 0
high = 100
population_size = 10000

population = np.random.uniform(low, high, size=population_size)

sample_size = 30
num_samples = 1000

sample_means = []

for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size, replace=False)
    sample_means.append(np.mean(sample))

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(population, bins=30, kde=True, color='blue', stat='density')
plt.title('Population Distribution (Uniform)')
plt.xlabel('Value')
plt.ylabel('Density')

plt.subplot(1, 2, 2)
sns.histplot(sample_means, bins=30, kde=True, color='orange', stat='density')
plt.title('Distribution of Sample Means')
plt.xlabel('Sample Mean')
plt.ylabel('Density')

plt.tight_layout()
plt.show()

# %%
# Question 15

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

population_mean = 100
population_std = 15
population_size = 10000

population = np.random.normal(loc=population_mean, scale=population_std, size=population_size)

sample_size = 30
num_samples = 1000

sample_means = []

for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size, replace=False)
    sample_means.append(np.mean(sample))

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(population, bins=30, kde=True, color='blue', stat='density')
plt.title('Population Distribution')
plt.xlabel('Value')
plt.ylabel('Density')

plt.subplot(1, 2, 2)
sns.histplot(sample_means, bins=30, kde=True, color='orange', stat='density')
plt.title('Distribution of Sample Means')
plt.xlabel('Sample Mean')
plt.ylabel('Density')

plt.tight_layout()
plt.show()

# %%
# Question 16

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():

    mean = 0
    std_dev = 1

    x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)

    pdf = norm.pdf(x, mean, std_dev)

    plt.figure(figsize=(10, 6))
    plt.plot(x, pdf, color='blue', label='Standard Normal Distribution (mean=0, std=1)')
    plt.title('Standard Normal Distribution')
    plt.xlabel('Z-Score')
    plt.ylabel('Probability Density')
    plt.axvline(0, color='red', linestyle='--', label='Mean (0)')
    plt.grid()
    plt.legend()
    plt.show()

plot_standard_normal_distribution()

# %%
# Question 17

import numpy as np
from scipy.stats import binom

n = 10
p = 0.5

random_variables = np.random.binomial(n, p, size=10)

probabilities = [binom.pmf(x, n, p) for x in random_variables]

for i in range(len(random_variables)):
    print(f"Random Variable: {random_variables[i]}, Probability: {probabilities[i]:.4f}")

x = np.arange(0, n+1)
y = binom.pmf(x, n, p)

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(x, y, marker='o', linestyle='-', color='blue')
plt.title('Binomial Distribution')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.grid()
plt.show()
# Out:
# Random Variable: 8, Probability: 0.0439
# Random Variable: 7, Probability: 0.1172
# Random Variable: 2, Probability: 0.0439
# Random Variable: 4, Probability: 0.2051
# Random Variable: 6, Probability: 0.2051
# Random Variable: 3, Probability: 0.1172
# Random Variable: 5, Probability: 0.2461
# Random Variable: 2, Probability: 0.0439
# Random Variable: 4, Probability: 0.2051
# Random Variable: 2, Probability: 0.0439

# %%
# Question 18

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(data_point, mean, std_dev):
    return (data_point - mean) / std_dev

mean = 100
std_dev = 15

data_point = 130

z_score = calculate_z_score(data_point, mean, std_dev)

print(f"Data Point: {data_point}")
print(f"Mean: {mean}, Standard Deviation: {std_dev}")
print(f"Z-Score: {z_score:.2f}")

x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, 0, 1)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Standard Normal Distribution', color='blue')
plt.axvline(z_score, color='red', linestyle='--', label=f'Z-Score: {z_score:.2f}')
plt.title('Standard Normal Distribution')
plt.xlabel('Z-Score')
plt.ylabel('Probability Density')
plt.legend()
plt.grid()
plt.show()
# Out:
# Data Point: 130
# Mean: 100, Standard Deviation: 15
# Z-Score: 2.00

# %%
# Question 19

import numpy as np
import scipy.stats as stats

population_mean = 100
sample_size = 30
sample_data = np.random.normal(loc=105, scale=10, size=sample_size)
sample_mean = np.mean(sample_data)
sample_std = np.std(sample_data, ddof=1)

z_statistic = (sample_mean - population_mean) / (sample_std / np.sqrt(sample_size))

p_value = 2 * (1 - stats.norm.cdf(abs(z_statistic)))

print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-Statistic: {z_statistic:.2f}")
print(f"P-Value: {p_value:.4f}")

alpha = 0.05

if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference from the population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference from the population mean.")
# Out:
# Sample Mean: 109.16
# Z-Statistic: 4.63
# P-Value: 0.0000
# Reject the null hypothesis: There is a significant difference from the population mean.

# %%
# Question 20

import numpy as np
import scipy.stats as stats

np.random.seed(0)
data = np.random.normal(loc=170, scale=10, size=100)

sample_mean = np.mean(data)
standard_error = stats.sem(data)

confidence_level = 0.95
alpha = 1 - confidence_level

ci_lower, ci_upper = stats.t.interval(confidence_level, df=len(data)-1, loc=sample_mean, scale=standard_error)

print(f"Sample Mean: {sample_mean:.2f}")
print(f"Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")

print(f"\nInterpretation: We are {confidence_level*100:.0f}% confident that the true population mean lies between {ci_lower:.2f} and {ci_upper:.2f}.")
# Out:
# Sample Mean: 170.60
# Confidence Interval: (168.59, 172.61)
#
# Interpretation: We are 95% confident that the true population mean lies between 168.59 and 172.61.

# %%
# Question 21

import numpy as np
import scipy.stats as stats

mean = 50
std_dev = 10
sample_size = 100

np.random.seed(0)
data = np.random.normal(loc=mean, scale=std_dev, size=sample_size)

sample_mean = np.mean(data)
standard_error = stats.sem(data)

confidence_level = 0.95
alpha = 1 - confidence_level

ci_lower, ci_upper = stats.t.interval(confidence_level, df=sample_size-1, loc=sample_mean, scale=standard_error)

print(f"Sample Mean: {sample_mean:.2f}")
print(f"Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample Mean: 50.60
# Confidence Interval: (48.59, 52.61)

# %%
# Question 22

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mean = 0
std_dev = 1

x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)

pdf = norm.pdf(x, mean, std_dev)

plt.figure(figsize=(10, 6))
plt.plot(x, pdf, color='blue', label='PDF of Normal Distribution')
plt.title('Probability Density Function (PDF) of Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.grid(alpha=0.5)
plt.axvline(mean, color='red', linestyle='--', label='Mean')
plt.legend()
plt.show()

# %%
# Question 23

from scipy.stats import poisson
import matplotlib.pyplot as plt
import numpy as np

lambda_value = 5
k_values = np.arange(0, 16)

cdf_values = poisson.cdf(k_values, lambda_value)

plt.figure(figsize=(10, 6))
plt.plot(k_values, cdf_values, marker='o', linestyle='-', color='blue')
plt.title('Cumulative Distribution Function (CDF) of Poisson Distribution')
plt.xlabel('Number of Events (k)')
plt.ylabel('Cumulative Probability')
plt.xticks(k_values)
plt.grid(alpha=0.5)
plt.axhline(y=0.95, color='red', linestyle='--', label='95% Probability')
plt.legend()
plt.show()

probability_up_to_5 = poisson.cdf(5, lambda_value)
print(f"Probability of receiving 5 or fewer events: {probability_up_to_5:.4f}")
# Out:
# Probability of receiving 5 or fewer events: 0.6160

# %%
# Question 24

import numpy as np

a = 0
b = 10

samples = np.random.uniform(low=a, high=b, size=1000)

expected_value = (a + b) / 2

print(f"Simulated Samples: {samples[:10]}...")
print(f"Expected Value: {expected_value}")
# Out:
# Simulated Samples: [4.00510464 4.10915734 1.03253221 5.19098939 0.96803219 8.89762136
#  0.61844783 4.4969443  2.84694066 1.54869416]...
# Expected Value: 5.0

# %%
# Question 25

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(0)
data1 = np.random.normal(loc=50, scale=10, size=1000)
data2 = np.random.normal(loc=60, scale=20, size=1000)

std_dev1 = np.std(data1)
std_dev2 = np.std(data2)

std_devs = pd.DataFrame({
    'Dataset': ['Dataset 1', 'Dataset 2'],
    'Standard Deviation': [std_dev1, std_dev2]
})

plt.figure(figsize=(8, 5))
plt.bar(std_devs['Dataset'], std_devs['Standard Deviation'], color=['blue', 'orange'])
plt.title('Comparison of Standard Deviations')
plt.ylabel('Standard Deviation')
plt.ylim(0, max(std_devs['Standard Deviation']) + 5)  # Set y-axis limit for better visibility
plt.grid(axis='y')

plt.show()

print(f"Standard Deviation of Dataset 1: {std_dev1}")
print(f"Standard Deviation of Dataset 2: {std_dev2}")
# Out:
# Standard Deviation of Dataset 1: 9.870331586690257
# Standard Deviation of Dataset 2: 19.36319967652846

# %%
# Question 26

import numpy as np
import pandas as pd

np.random.seed(0)
data = np.random.normal(loc=50, scale=10, size=1000)
df = pd.DataFrame(data, columns=['Data'])

data_range = df['Data'].max() - df['Data'].min()

Q1 = df['Data'].quantile(0.25)
Q3 = df['Data'].quantile(0.75)
IQR = Q3 - Q1

print(f"Range: {data_range}")
print(f"Interquartile Range (IQR): {IQR}")
# Out:
# Range: 58.05498168821509
# Interquartile Range (IQR): 13.053706612482685

# %%
# Question 27

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(0)
data = np.random.normal(loc=50, scale=10, size=1000)
df = pd.DataFrame(data, columns=['Original Data'])

df['Z-Score Normalized'] = (df['Original Data'] - df['Original Data'].mean()) / df['Original Data'].std()

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(df['Original Data'], bins=30, kde=True, color='blue')
plt.title('Original Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
sns.histplot(df['Z-Score Normalized'], bins=30, kde=True, color='orange')
plt.title('Z-Score Normalized Data Distribution')
plt.xlabel('Z-Score')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Question 28

import numpy as np
from scipy.stats import skew, kurtosis

def calculate_skewness_kurtosis(size=1000, mean=0, std_dev=1):
    data = np.random.normal(loc=mean, scale=std_dev, size=size)

    skewness = skew(data)
    kurt = kurtosis(data)

    return skewness, kurt

skewness, kurtosis_value = calculate_skewness_kurtosis()
print(f"Skewness: {skewness}, Kurtosis: {kurtosis_value}")
# Out:
# Skewness: 0.12205441828250321, Kurtosis: -0.2021722995065276
